# %%
def minDistance(height, width, tree, squirrel, nuts):
    distances = [abs(n[0] - tree[0]) + abs(n[1] - tree[1]) for n in nuts]
    total_dist = sum(distances)
    ans = float('inf')
    for i in range(len(nuts)):
        first_nut = abs(nuts[i][0] - squirrel[0]) + abs(nuts[i][1] - squirrel[1])
        ans = min(ans, first_nut + 2 * total_dist - distances[i])
    return ans

# %%
def minDistance(height, width, tree, squirrel, nuts):
    total_dist = sum(abs(n[0] - tree[0]) + abs(n[1] - tree[1]) for n in nuts)
    ans = float('inf')
    for i in range(len(nuts)):
        s_first_nut = abs(nuts[i][0] - squirrel[0]) + abs(nuts[i][1] - squirrel[1])
        t_first_nut = abs(nuts[i][0] - tree[0]) + abs(nuts[i][1] - tree[1])
        ans = min(ans, s_first_nut + 2 * total_dist - t_first_nut)
    return ans

# %%
minDistance(5, 7, [2,2], [4,4], [[3,0],[2,5]])
# Out:
# 12
