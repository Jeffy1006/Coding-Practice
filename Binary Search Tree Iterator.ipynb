# %%
class BSTIterator:
    def __init__(self, root):
        self.stack = []
        self.pushLeft(root)
    
    def next(self):
        node = self.stack.pop()
        if node.right:
            pushLeft(node.right)
        return node.val
    
    def hasNext(self):
        return self.stack
        
        
    def pushLeft(self, root):
        while root:
            stack.append(root)
            root = root.left
