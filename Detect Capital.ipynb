# %%
def detectCapitalUse(s):
    return s.islower() or s.isupper() or (s[0].isupper() and s[1:].islower())

# %%
def detectCapitalUse(s):
    return s.islower() or s.isupper() or s.istitle()

# %%
def detectCapitalUse(s):
    return all(ord(c) > 96 for c in s) or \
            all(ord(c) < 91 for c in s) or \
            (ord(s[0]) < 91 and all(ord(c) > 96 for c in s[1:]))
