# %%
def intersect(nums1, nums2):
    hashset1 = set(nums1)
    hashset2 = set(nums2)
    
    return list(hashset1.intersection(hashset2))

# %%
intersect([4,9,5], [9,4,9,8,4])
# Out:
# [9, 4]

# %%
def intersectII(nums1, nums2):
    if len(nums1) > len(nums2):
        nums1, nums2 = nums2, nums1
    hashmap = {}
    for num in nums1:
        hashmap[num] = 1 + hashmap.get(num, 0)
    res = []
    for num in nums2:
        if num in hashmap and hashmap[num] > 0:
            res.append(num)
            hashmap[num] -= 1
    return res

# %%
def intersectII(nums1, nums2):
    nums1.sort()
    nums2.sort()
    i = j = 0
    res = []
    while i < len(nums1) and j < len(nums2):
        if nums[1] == nums[2]:
            res.append(nums1[i])
            i += 1
            j += 1
        elif nums1[i] < nums2[j]:
            i += 1
        else: 
            j += 1
    return res
