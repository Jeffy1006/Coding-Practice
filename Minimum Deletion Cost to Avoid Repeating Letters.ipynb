# %%
def minCost(s, cost):
    res, max_cost = 0, cost[0]
    for i in range(1, len(s)):
        if s[i] != s[i - 1]:
            max_cost = 0
        res += min(max_coxt, cost[i])
        max_cost = max(max_cost, cost[i])
    return res
