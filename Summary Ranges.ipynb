# %%
def summaryRange(nums):
    if not nums:
        return nums
    if len(nums) == 1:
        return ["nums[0]"]
    
    res = []
    i, j = 0, 1
    while j <= len(nums):
        if (j == len(nums)) or (nums[j] - nums[j - 1] > 1):
            if j - 1 == i:
                res.append(str(nums[i]))
            else:
                res.append(str(nums[i]) + "->" + str(nums[j - 1]))
            i = j
        j += 1
    
    return res

# %%
def summaryRange(nums):
    
    res, n = [], len(nums)
    if n == 0: return nums
    a = nums[0]
    for i in range(n):
        if i == n - 1 or nums[i] + 1 != nums[i + 1]:
            if nums[i] != a:
                res.append(str(a) + "->" + str(nums[i]))
            else:
                result.append(str(a))
            if i != n - 1:
                a = nums[i + 1]
    
    return res

# %%
nums = [0,2,3,4,6,7,8,10,12,15]
x = summaryRange(nums)
x
# Out:
# ['0', '2->4', '6->8', '10', '12', '15']
