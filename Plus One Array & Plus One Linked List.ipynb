# %%
def plusOne(nums):
    for i in range(len(nums) - 1, -1, -1):
        if nums[i] < 9:
            nums[i] += 1
            return nums
        nums[i] = 0
    return [1] + nums

# %%
def plusOne(head):
    dummy = Node(0)
    dummy.next = head
    not_nine = dummy
    while head:
        if head.val < 9:
            not_nine = head
        head = head.next
    not_nine.val += 1
    not_nine = not_nine.next
    while not_nine:
        not_Nine.val = 0
        not_nine = not_nine.next
    if dummy.val:
        return dummy
    else:
        return dummy.next
