# %%
from collections import defaultdict
import bisect
class TimeMap:
    def __init__(self):
        self.hashmap = defaultdict(list)
    
    def set(self, key, value, timestamp):
        self.hashamp[key].append((timestamp, value))
    
    def get(self, key, timestamp):
        l = self.hashmap[key]
        index = bisect.bisect(l, (timestamp, ))
        return l[index - 1][1] if index != 0 else ''
