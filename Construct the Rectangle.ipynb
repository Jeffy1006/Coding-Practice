# %%
def constructRectangle(area):
    i, j = 1, area
    count = 0
    while i < j:
        i += 1
        if area % i == 0:
            j = area // i
    return [i,  j]

# %%
import math
def constructRectangle(area):
    mid = int(math.sqrt(area))
    count = 0
    while mid > 0:
        if area % mid == 0:
            return [(area // mid), mid]
        mid -= 1
        count += 1

# %%
constructRectangle(12)
# Out:
# [4, 3]
