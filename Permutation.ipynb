# %%
def permute(nums):
    res = []
    
    def helper(pt):
        if pt == len(nums):
            res.append(tuple(nums[:]))
            return
        
        for i in range(pt, len(nums)):
            nums[pt], nums[i] = nums[i], nums[pt]
            helper(pt + 1)
            nums[pt], nums[i] = nums[i], nums[pt]
    
    helper(0)
    return res

# %%
def permute(nums):
    res = []
    
    if len(nums) == 1:
        return [nums[:]]
    
    for i in range(len(nums)):
        n = nums.pop(0)
        perms = permute(nums)
        
        for perm in perms:
            perm.append(n)
        result.extend(perms)
        nums.append(n)  
        
    return res

# %%
a = set(permutation([1,2,3,4]))

# %%
import itertools
b = set(list(itertools.permutations([1,2,3,4], 4)))

# %%
a == b
# Out:
# True
