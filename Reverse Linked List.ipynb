# %%
def reverseLL(head):
    
    prev, cur = None, head
    while cur:
        tmp = cur.next
        cur.next = prev
        prev = cur
        cur = tmp
    
    return prev

# %%
def reverseLL(head):
    
    if not node or not node.next:
        return node
        
    newHead = reverseLL(node.next)
    node.next.next = node
    node.next = None
    
    return newHead
