# %%
class Stack:
    def __init__(self):
        self.queue1 = []
        self.queue2 = []
        self.top = None
        self.size = 0
    
    
    def push(self, val):
        self.queue1.append(val)
        self.top = val
        self.size += 1
    
    def pop(self):
        if self.size == 0:
            return None

        while self.size > 1:
            self.queue2.append(self.queue1.pop(0))
            
        res = self.queue1.pop(0)
        self.size -= 1
        
        if self.size > 0:
            for i in range(self.size - 1)
                self.queue1.append(self.queue2.pop(0))
            self.top = self.queue2.pop(0)
            self.queue1.append(self.top)
        else:
            self.top = None
            
        
        return res
    
    def top(self):
        return self.top
    
    def empty(self):
        return True if self.stack == 0 else False
