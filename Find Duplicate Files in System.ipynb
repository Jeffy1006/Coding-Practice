# %%
from collections import defaultdict
def findDuplicates(paths):
    duplicates = defaultdict(list)
    for path in paths:
        p = path.split(' ')
        for i in range(1, len(p)):
            open_, close_ = p[i].index('('), p[i].index(')')
            duplicates[p[i][open_ + 1: close_]].append(p[0] + '/' + p[i][:open_])
    return [l for l in duplicates.values() if len(l) > 1]

# %%
paths = ["root/a 1.txt(abcd) 2.txt(efgh)", "root/c 3.txt(abcd)", "root/c/d 4.txt(efgh)", "root 4.txt(efgh)"]
findDuplicates(paths)
# Out:
# [['root/a/1.txt', 'root/c/3.txt'],
#  ['root/a/2.txt', 'root/c/d/4.txt', 'root/4.txt']]

# %%
paths = ["root/a 1.txt(abcd) 2.txt(efgh)", "root/c 3.txt(abcd)", "root/c/d 4.txt(efgh)"]
findDuplicates(paths)
# Out:
# [['root/a/1.txt', 'root/c/3.txt'], ['root/a/2.txt', 'root/c/d/4.txt']]
