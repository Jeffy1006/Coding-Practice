# %%
def sumSubarrayMins(nums):
    n = len(nums)
    
    left = [1] * n
    dec_q = [(nums[0], 1)]
    
    for i in range(1, n):
        while dec_q and nums[i] <= dec_1[-1][0]:
            left[i] += dec_q.pop()[1]
        dec_q.append(nums[i], left[i])
    
    right = [1] * n
    dec_q = [(nums[-1], 1)]
    
    for i in range(n - 2, -1, -1):
        while dec_q and nums[i] < dec_1[-1][0]:
            right[i] += dec_q.pop()[1]
        dec_q.append(nums[i], right[i])
    
    ans = 0
    
    for i in range(n):
        ans += nums[i] * left[i] * right[i]
    
    return ans % (10**9 + 7)
