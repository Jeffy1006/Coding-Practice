# %%
def PlusOne(digits):
    carry = 1
    for i in range(len(digits)-1, -1, -1):
        if arr[i] < 9:
            arr[i] += carry
            carry = 0
            break
        else:
            arr[i] = 0

    return [1] + digits if carry else digits
