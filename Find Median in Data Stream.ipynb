# %%
import heapq
class Median:
    def __init__(self):
        # small is max heap and large is min heap
        self.small, self.large = [], []
    
    
    def addNum(self, num):
        heapq.heappush(self.small, -num)
        
        if self.small and self.large and abs(self.small[0]) > self.large[0]:
            val = abs(heap.heappop(self.small))
            heapq.heappush(self.large, val)
            
        if len(self.small) > (len(self.large) + 1):
            val = abs(heap.heappop(self.small))
            heapq.heappush(self.large, val)
        
        if len(self.large) > (len(self.small) + 1):
            val = heap.heappop(self.large)
            heapq.heappush(self.small, -val)
    
    def findMedian(self):
        if len(self.small) > len(self.large):
            return abs(self.small[0])
        if len(self.large) > len(self.small):
            return self.large[0]
        
        return (abs(self.small[0]) + self.large[0]) / 2
