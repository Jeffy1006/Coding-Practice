# %%
class Vector2D:
    def __init__(self, vectors):
        self.vectors = vectors
        self.row = 0
        self.col = 0
        
    def next(self):
        if self.col < len(self.vectors[self.row]):
            self.col += 1
            return self.vectors[self.row][self.col - 1]
        
        self.row += 1
        self.col = 1
        while self.row < len(self.vectors):
            if len(self.vectors[self.row]) == 0:
                self.row += 1
         
        if self.row < len(self.vectors):
            return self.vectors[self.row][self.col - 1]
        else:
            return None
    
    def hasNext(self):
        if self.row < len(self.vectors) and self.col < len(self.vectors[self.row]):
            return True
        else:
            return False

# %%
class Vector2D:
    def __init__(self, vectors):
        self.vectors = vectors
        self.row = 0
        self.col = 0
        
    def next(self):
        if self.hasNext():
            self.col += 1
            return self.vectors[self.row][self.col - 1]
        else:
            return None
    
    def hasNext(self):
        while self.row < len(self.vectors):
            if self.col < len(self.vectors[self.row]):
                return True
            self.row += 1
            self.col = 0
        
        return False
