# %%
def getSum(a, b):
    mask = 0xffffffff
    while b:
        SUM = (a ^ b) & mask
        carry = ((a & b) << 1) & mask
        a = SUM
        b = carry
    if (a >> 31) & 1:
        return ~(a ^ mask)
    return a

# %%
getSum(-2, -1)
# Out:
# -3
