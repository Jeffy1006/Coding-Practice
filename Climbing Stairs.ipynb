# %%
def climbStairs(n):
    def helper(remain):
        if remain == 0:
            return 1
        if remain < 0:
            return 0
        if remain in mem:
            return mem[remain]
        
        mem[remain] = helper(remain - 1) + helper(remain - 2)
        return mem[remain]
    
    mem = {}
    return helper(n)

# %%
def climbStairs(n):
    one, two = 1, 1
    
    for i in range(n - 1):
        one, two = one + two, one
    
    return one

# %%
def climbStairs(n):
    if n < 2: return n
    
    one, two = 2, 1
    
    for i in range(n - 2):
        one, two = one + two, one
    
    return one

# %%
climbStairs(15)
# Out:
# 987

# %%
climbStairs(4)
# Out:
# 5
