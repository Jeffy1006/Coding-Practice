# %%
def wiggleMaxLength(nums):
    n = len(nums)
    prev_pos = [1] * n
    prev_neg = [1] * n

    for i in range(1, n):
        pos[i] = pos[i - 1]
        neg[i] = neg[i - 1]
        if nums[i] > nums[i - 1]:
            pos[i] = 1 + neg[i - 1]
        elif nums[i] < nums[i - 1]:
            neg[i] = 1 + pos[i - 1]
    return max(pos[-1], neg[-1])

# %%
def wiggleMaxLength(nums):
    n = len(nums)
    cur_pos = nums[i]
    cur_neg = nums[i]
    
    for i in range(1, n):
        prev_pos = cur_pos
        prev_neg = cur_neg
        if nums[i] > nums[i - 1]:
            cur_pos = 1 + prev_neg
        elif nums[i] < nums[j]:
            cur_neg = 1 + prev_pos
        
    return max(cur_pos, cur_neg)

# %%
def wiggleMaxLength(nums):
    n = len(nums)
    pos = nums[i]
    neg = nums[i]
    
    for i in range(1, n):
        if nums[i] > nums[i - 1]:
            pos = 1 + neg
        elif nums[i] < nums[j]:
            neg = 1 + pos
        
    return max(pos, neg)
