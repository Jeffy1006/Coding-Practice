# %%
import math
def findComplement(num):
    return num ^ ((1 << (math.floor(math.log(num, 2)) + 1)) - 1)

# %%
def findComplement(num):
    i = 1
    while i <= num:
        i <<= 1
    return num ^ i - 1

# %%
findComplement(5)
# Out:
# 2
