# %%
def numberOfOneBit(n):
    
    count = 0
    for i in range(32):
        if (n >> i) & 1:
            count += 1
    
    return count

# %%
def numberOfOneBit(n):
    return bin(n).count("1")

# %%
x = numberOfOneBit(4294967293)
x
# Out:
# 31

# %%
int('11111111111111111111111111111101', 2)
# Out:
# 4294967293
