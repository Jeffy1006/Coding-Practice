# %%
def invertTree(root):
    # one requirement is the invertTree function must return the root
    def swap(node):
        if not node: return None

        invertTree(node.left)
        invertTree(node.right)

        node.left, node.right = node.right, node.left
    
    swap(root)
    return root
