# %%
# Avoid Split
def countSegment(s):
    return sum(s[i] != ' ' and (i == 0 or s[i - 1] == ' ') for i in range(len(s)))

# %%
def countSegment(s):
    s = s.strip()
    if len(s) < 1: return 0
    
    count = 0
    for i in range(len(s) - 1):
        if s[i] == ' ' and s[i + 1] != ' ':
            count += 1
    return count + 1
