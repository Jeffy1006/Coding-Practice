# %%
def finBad(n):
    if n == 1: return 1
    low, high = 1, n
    while low <= high:
        mid = (high + low) // 2
        if not isBadVersion(mid):
            if isBadVersion(mid + 1):
                return mid
            else:
                low = mid + 1
        else:
            if mid == low or not isBadVersion(mid - 1):
                return mid
            else:
                high = mid - 1

# %%
def finBad(n):
    low, high = 1, n
    while low < high:
        mid = (high + low) // 2
        if not isBadVersion(mid):
            low = mid + 1
        else:
            high = mid
    
    return left
