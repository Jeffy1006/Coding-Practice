# %%
def inorderTraversal(root):
    def helper(node):
        if node:
            helper(node.left)
            res.append(node.val)
            helper(node.right)
    
    res = []
    helper(root)
    return res

# %%
def inorderTraversal(root):
    res = []
    stack = []
    cur = root
    
    while cur or stack:
        while cur:
            stack.append(cur)
            cur = cur.left
        cur = stack.pop()
        res.append(cur)
        cur = cur.right
    
    return res

# %%
def inorderTraversal(root):
    res = []
    stack = []
    cur = root
    
    while cur or stack:
        if cur:
            cur = cur.left
        elif stack:
            cur = stack.pop()
            res.append(cur)
            cur = cur.right
    
    return res
