# %%
def checkPerfectNumber(num):
    if num <= 0: return False
    ans, SQRT = 1, int(num**0.5)
    ans = sum(i + num // i for i in range(1, SQRT + 1) if num % i == 0)
    if num == SQRT ** 2: ans -= SQRT
    return ans - num  == num
