# %%
class StockSpanner(object):

    def __init__(self):
        self.stack = []
        self.index = -1

    def next(self, price):
        self.index += 1
        while self.stack and price >= self.stack[-1][1]:
            self.stack.pop()
        i = stack[-1][0] if stack else -1
        stack.append((self.index, price))
        return self.index - i
