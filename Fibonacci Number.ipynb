# %%
def fib(n):
    f0, f1 = 0, 1
    for _ in range(2, n + 1):
        f0, f1 = f1, f0 + f1
    return f1 if num > 0 else f0

# %%
def fib(n):
    mem = {}
    def helper(n):
        if n < 2: return n
        
        if n - 1 not in mem: mem[n - 1] = helper(n - 1)
        if n - 2 not in mem: mem[n - 2] = helper(n - 2)
        return mem[n - 1] + mem[n - 2]
    return helper(n)

# %%
from functools import lru_cache
@lru_cache(maxsize = None)
def fib(n):
    if n < 2: return n
    return fib(n - 1) + fib( n - 2)

# %%
def fib(n):
    if n < 2: return n
    mem = (0, 1)
    for _ in range(2, n + 1):
        mem = (mem[1], mem[0] + mem[1])
    return mem[1]
