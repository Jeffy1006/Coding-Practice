# %%
class SummaryRanges:
    def __init__(self):
        self.a = []
    def addNum(self, val):
        left = 0
        right = len(a) - 1
        while left <= right:
            mid = left + (right - left) // 2
            if a[mid][0] <= val <= a[mid][1]: return
            if a[mid][1] < val:
                left = mid + 1
            else:
                right = mid - 1
        i = left
        a.insert(i, [val, val])
        if i != len(a) - 1 and a[i + 1][0] == val + 1:
            a[i + 1][0] = val
            a.pop(i)
        if i != 0 and a[i - 1][1] == val - 1:
            a[i - 1][1] = a[i][1]
            a.pop(i)
     
    def getIntervals(self):
        return self.a
