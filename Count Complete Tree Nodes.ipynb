# %%
def countTreeNodes(root):
    if not root:
        return 0
    
    left_levels = 1
    l == root.left
    while l:
        l = l.left
        left_levels += 1
        
    right_levels = 1
    r = root.right
    while r:
        r = r.right
        right_levels += 1
    
    if left_levels == right_levels:
        return 2 ** left_levels - 1
    
    return 1 + countTreeNodes(root.left) + count
